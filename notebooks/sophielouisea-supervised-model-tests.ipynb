# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preprocessing-of-data-subset" data-toc-modified-id="Preprocessing-of-data-subset-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preprocessing of data subset</a></span></li></ul></div>

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Preprocessing of data subset

# %%
file_path = '/Users/sophie/code/DealMatch/DealMatch/raw_data/hubspot_sample.xlsx'
df = pd.read_excel(file_path)
df.head()
# Out:
#    Unnamed: 0     Deal ID  Datum Ident  Grund für gewonnenen Abschluss  \
# 0       30841  5417776965          NaN                             NaN
# 1       78396  1852821401          NaN                             NaN
# 2       28817  5507051086          NaN                             NaN
# 3       43990  4026327229          NaN                             NaN
# 4       55936  2751755213          NaN                             NaN
#
#    Jährlicher Vertragswert Notizen Datum der letzten Änderung  \
# 0                      NaN     NaN        2021-09-04 18:01:00
# 1                      NaN     NaN        2022-02-08 08:58:00
# 2                      NaN     NaN        2022-02-01 11:22:00
# 3                      NaN     NaN        2021-09-05 09:36:00
# 4                      NaN     NaN        2022-02-01 11:22:00
#
#    Berater: Firma (Firmenname)              Adresszeile Ansprache versendet  \
# 0                          NaN            Im Neuacker 1                 NaT
# ...
